# %%
library(dplyr)
library(ggplot2)
library(readr)

# %%
getwd()
setwd("球隊25人名單 薪資")
# Out:
# [1] "D:/jupyter notebook 工作區/棒球球員薪資數據/球隊25人名單 薪資"
# Error in setwd("球隊25人名單 薪資"): 無法變更工作目錄
# Traceback:
#
# 1. setwd("球隊25人名單 薪資")

# %%
getwd()
# Out:
# [1] "D:/jupyter notebook 工作區/棒球球員薪資數據/球隊25人名單 薪資"

# %%
dir()
# Out:
#   [1] "Arizona Diamondbacks 2011.csv"  "Arizona Diamondbacks 2012.csv"
#   [3] "Arizona Diamondbacks 2013.csv"  "Arizona Diamondbacks 2014.csv"
#   [5] "Arizona Diamondbacks 2015.csv"  "Arizona Diamondbacks 2016.csv"
#   [7] "Arizona Diamondbacks 2017.csv"  "Arizona Diamondbacks 2018.csv"
#   [9] "Arizona Diamondbacks 2019.csv"  "Atlanta Braves 2011.csv"
#  [11] "Atlanta Braves 2012.csv"        "Atlanta Braves 2013.csv"
#  [13] "Atlanta Braves 2014.csv"        "Atlanta Braves 2015.csv"
#  [15] "Atlanta Braves 2016.csv"        "Atlanta Braves 2017.csv"
#  [17] "Atlanta Braves 2018.csv"        "Atlanta Braves 2019.csv"
#  [19] "Baltimore Orioles 2011.csv"     "Baltimore Orioles 2012.csv"
#  [21] "Baltimore Orioles 2013.csv"     "Baltimore Orioles 2014.csv"
#  [23] "Baltimore Orioles 2015.csv"     "Baltimore Orioles 2016.csv"
#  [25] "Baltimore Orioles 2017.csv"     "Baltimore Orioles 2018.csv"
#  [27] "Baltimore Orioles 2019.csv"     "Boston Red Sox 2011.csv"
# ...

# %%
library(stringr)
csv <- read_csv('Arizona Diamondbacks 2011.csv')
str(csv)
print(csv[3])
x <- mapply(str_replace_all,csv[1],pattern = "\r|\t|\n",replacement = "")
y <- sapply(csv[5],parse_number)
print(x)
print(y)
# Out:
# Parsed with column specification:
# cols(
#   Active.Players..38. = col_character(),
#   Age = col_integer(),
#   Pos. = col_character(),
#   Status = col_character(),
#   Base.Salary = col_character(),
#   Signing.Bonus = col_character(),
#   Incentives = col_character(),
#   Payroll.Salary = col_character(),
#   Adj...Salary = col_character(),
#   Payroll.. = col_double(),
#   Lux..Tax.Salary = col_integer()
# )
# Classes 'tbl_df', 'tbl' and 'data.frame':	38 obs. of  11 variables:
#  $ Active.Players..38.: chr  "Johnson\r\n\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\tKelly Johnson" "Saunders\r\n\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\tJoe Saunders" "Young\r\n\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\tChris Young" "Drew\r\n\t\t\t\t\t\t\t\t\t\t\r\n\t\t\t\t\t\t\t\t\t\tStephen Drew" ...
#  $ Age                : int  29 29 27 28 23 34 28 27 39 29 ...
#  $ Pos.               : chr  "2B" "SP" "RF" "2B" ...
#  $ Status             : chr  "Arb 3" "Arb 2" "Vet" "Arb 2" ...
# ...
